# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/MyDrive/TrainYOLOv8CustomDataset'

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %% [markdown]
# # Install YOLOv8:

# %%
# Pip install (recommended)
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 10.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Train model**

# %% [markdown]
# # **Model 1**

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml') # load pre trained model
# Use the model
results = model.train(data=os.path.join(ROOT_DIR,'data1.yaml'), epochs=30,batch=8,optimizer='Adamax',lr0=0.01,seed=42)
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Performance Analysis**

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

results_path = '/content/runs/detect/train/results.csv'  # path for the results.csv of your custom model
results = pd.read_csv(results_path)

# Remove leading spaces and replace slashes in column names
results.columns = results.columns.str.strip().str.replace('/', '_')

# Print column names to identify the correct ones
print(results.columns)

# Plotting Loss vs epochs
plt.figure()
plt.plot(results['epoch'], results['train_box_loss'], label='train box loss')
plt.plot(results['epoch'], results['val_box_loss'], label='val box loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()

# Plotting Validation accuracy vs epochs
plt.figure()
plt.plot(results['epoch'], results['metrics_mAP50(B)'] * 100)
plt.grid()
plt.title('mAP50 vs epochs')
plt.ylabel('mAP50')
plt.xlabel('epochs')

plt.show()
# Out:
# Index(['epoch', 'train_box_loss', 'train_cls_loss', 'train_dfl_loss',
#        'metrics_precision(B)', 'metrics_recall(B)', 'metrics_mAP50(B)',
#        'metrics_mAP50-95(B)', 'val_box_loss', 'val_cls_loss', 'val_dfl_loss',
#        'lr_pg0', 'lr_pg1', 'lr_pg2'],
#       dtype='object')

# %% [markdown]
# # **Model 2**

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml') # load pre trained model
# Use the model
results = model.train(data=os.path.join(ROOT_DIR,'data1.yaml'), epochs=50,batch=16,optimizer='Adam',lr0=0.01,seed=42)
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Performance Analysis**

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

results_path = '/content/runs/detect/train/results.csv'  # path for the results.csv of your custom model
results = pd.read_csv(results_path)

# Remove leading spaces and replace slashes in column names
results.columns = results.columns.str.strip().str.replace('/', '_')

# Print column names to identify the correct ones
print(results.columns)

# Plotting Loss vs epochs
plt.figure()
plt.plot(results['epoch'], results['train_box_loss'], label='train box loss')
plt.plot(results['epoch'], results['val_box_loss'], label='val box loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()

# Plotting Validation accuracy vs epochs
plt.figure()
plt.plot(results['epoch'], results['metrics_mAP50(B)'] * 100)
plt.grid()
plt.title('mAP50 vs epochs')
plt.ylabel('mAP50')
plt.xlabel('epochs')

plt.show()
# Out:
# Index(['epoch', 'train_box_loss', 'train_cls_loss', 'train_dfl_loss',
#        'metrics_precision(B)', 'metrics_recall(B)', 'metrics_mAP50(B)',
#        'metrics_mAP50-95(B)', 'val_box_loss', 'val_cls_loss', 'val_dfl_loss',
#        'lr_pg0', 'lr_pg1', 'lr_pg2'],
#       dtype='object')

# %% [markdown]
# # **Model 3**

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml') # load pre trained model
# Use the model
results = model.train(data=os.path.join(ROOT_DIR,'data1.yaml'), epochs=30,batch=8,optimizer='SGD',lr0=0.01,seed=42)
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Performance Analysis**

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

results_path = '/content/runs/detect/train2/results.csv'  # path for the results.csv of your custom model
results = pd.read_csv(results_path)

# Remove leading spaces and replace slashes in column names
results.columns = results.columns.str.strip().str.replace('/', '_')

# Print column names to identify the correct ones
print(results.columns)

# Plotting Loss vs epochs
plt.figure()
plt.plot(results['epoch'], results['train_box_loss'], label='train box loss')
plt.plot(results['epoch'], results['val_box_loss'], label='val box loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()

# Plotting Validation accuracy vs epochs
plt.figure()
plt.plot(results['epoch'], results['metrics_mAP50(B)'] * 100)
plt.grid()
plt.title('mAP50 vs epochs')
plt.ylabel('mAP50')
plt.xlabel('epochs')

plt.show()
# Out:
# Index(['epoch', 'train_box_loss', 'train_cls_loss', 'train_dfl_loss',
#        'metrics_precision(B)', 'metrics_recall(B)', 'metrics_mAP50(B)',
#        'metrics_mAP50-95(B)', 'val_box_loss', 'val_cls_loss', 'val_dfl_loss',
#        'lr_pg0', 'lr_pg1', 'lr_pg2'],
#       dtype='object')

# %% [markdown]
# # **Model 4**

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml') # load pre trained model
# Use the model
results = model.train(data=os.path.join(ROOT_DIR,'data1.yaml'), epochs=50,batch=16,optimizer='AdamW',lr0=0.01,seed=42)
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Performance Analysis**

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

results_path = '/content/runs/detect/train3/results.csv'  # path for the results.csv of your custom model
results = pd.read_csv(results_path)

# Remove leading spaces and replace slashes in column names
results.columns = results.columns.str.strip().str.replace('/', '_')

# Print column names to identify the correct ones
print(results.columns)

# Plotting Loss vs epochs
plt.figure()
plt.plot(results['epoch'], results['train_box_loss'], label='train box loss')
plt.plot(results['epoch'], results['val_box_loss'], label='val box loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()

# Plotting Validation accuracy vs epochs
plt.figure()
plt.plot(results['epoch'], results['metrics_mAP50(B)'] * 100)
plt.grid()
plt.title('mAP50 vs epochs')
plt.ylabel('mAP50')
plt.xlabel('epochs')

plt.show()
# Out:
# Index(['epoch', 'train_box_loss', 'train_cls_loss', 'train_dfl_loss',
#        'metrics_precision(B)', 'metrics_recall(B)', 'metrics_mAP50(B)',
#        'metrics_mAP50-95(B)', 'val_box_loss', 'val_cls_loss', 'val_dfl_loss',
#        'lr_pg0', 'lr_pg1', 'lr_pg2'],
#       dtype='object')

# %% [markdown]
# # **Model 5**

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml') # load pre trained model
# Use the model
results = model.train(data=os.path.join(ROOT_DIR,'data1.yaml'), epochs=50,batch=16,optimizer='AdamW',lr0=0.001,seed=42)
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Performance Analysis**

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

results_path = '/content/runs/detect/train2/results.csv'  # path for the results.csv of your custom model
results = pd.read_csv(results_path)

# Remove leading spaces and replace slashes in column names
results.columns = results.columns.str.strip().str.replace('/', '_')

# Print column names to identify the correct ones
print(results.columns)

# Plotting Loss vs epochs
plt.figure()
plt.plot(results['epoch'], results['train_box_loss'], label='train box loss')
plt.plot(results['epoch'], results['val_box_loss'], label='val box loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()

# Plotting Validation accuracy vs epochs
plt.figure()
plt.plot(results['epoch'], results['metrics_mAP50(B)'] * 100)
plt.grid()
plt.title('mAP50 vs epochs')
plt.ylabel('mAP50')
plt.xlabel('epochs')

plt.show()
# Out:
# Index(['epoch', 'train_box_loss', 'train_cls_loss', 'train_dfl_loss',
#        'metrics_precision(B)', 'metrics_recall(B)', 'metrics_mAP50(B)',
#        'metrics_mAP50-95(B)', 'val_box_loss', 'val_cls_loss', 'val_dfl_loss',
#        'lr_pg0', 'lr_pg1', 'lr_pg2'],
#       dtype='object')

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml') # load pre trained model
# Use the model
results = model.train(data=os.path.join(ROOT_DIR,'data1.yaml'), epochs=110,batch=15)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# # **Performance Analysis**

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

results_path = '/content/drive/MyDrive/Prediction 1/results (2).csv'  # path for the results.csv of your custom model
results = pd.read_csv(results_path)

# Remove leading spaces and replace slashes in column names
results.columns = results.columns.str.strip().str.replace('/', '_')

# Print column names to identify the correct ones
print(results.columns)

# Plotting Loss vs epochs
plt.figure()
plt.plot(results['epoch'], results['train_box_loss'], label='train box loss')
plt.plot(results['epoch'], results['val_box_loss'], label='val box loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()

# Plotting Validation accuracy vs epochs
plt.figure()
plt.plot(results['epoch'], results['metrics_mAP50(B)'] * 100)
plt.grid()
plt.title('mAP50 vs epochs')
plt.ylabel('mAP50')
plt.xlabel('epochs')

plt.show()
# Out:
# Index(['epoch', 'train_box_loss', 'train_cls_loss', 'train_dfl_loss',
#        'metrics_precision(B)', 'metrics_recall(B)', 'metrics_mAP50(B)',
#        'metrics_mAP50-95(B)', 'val_box_loss', 'val_cls_loss', 'val_dfl_loss',
#        'lr_pg0', 'lr_pg1', 'lr_pg2'],
#       dtype='object')

# %% [markdown]
# # Inferencing

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt conf=0.40 source=/content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/train/Dead_Fish_train220.jpg
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/train/Dead_Fish_train220.jpg: 640x480 1 Dead Fish, 93.4ms
# Speed: 4.4ms preprocess, 93.4ms inference, 91.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
