# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/MyDrive/TrainYOLOv8'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 5.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# # **Model - 1**

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

results = model.train(data=os.path.join(ROOT_DIR,'data_config1.yaml'),optimizer='Adam', epochs=50,batch=16,lr0=0.01)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Model 2**

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

results = model.train(data=os.path.join(ROOT_DIR,'data_config1.yaml'),optimizer='Adam', epochs=100,batch=32,lr0=0.01)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Model 3**

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

results = model.train(data=os.path.join(ROOT_DIR,'data_config1.yaml'),optimizer='AdamW', epochs=100,batch=32,lr0=0.01)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Model 4**

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

results = model.train(data=os.path.join(ROOT_DIR,'data_config1.yaml'),optimizer='AdamW', epochs=150,batch=32,lr0=0.001)
# Out:
# Ultralytics YOLOv8.1.46 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')  # load a custom model

# Predict with the model
results = model('/content/drive/MyDrive/Raspberry Pi/Test Images',save=True,conf=0.4)  # predict on an image
# Out:
# image 1/3 /content/drive/MyDrive/Raspberry Pi/Test Images/61wN0bSvL6L.jpg: 544x640 2 Goldfishs, 111.6ms
# image 2/3 /content/drive/MyDrive/Raspberry Pi/Test Images/Guppy-and-goldfish (8).jpg: 320x640 1 Goldfish, 1 Guppy, 69.7ms
# image 3/3 /content/drive/MyDrive/Raspberry Pi/Test Images/Images_train001.jpeg: 480x640 1 Goldfish, 74.3ms
# Speed: 2.7ms preprocess, 85.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict

# %%
# !pip install ultralytics==8.0.222

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/NewNew/best.pt conf=0.25 source=/content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/Videos_Test
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/16 /content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/Videos_Test/03-1024x681.jpg: 448x640 1 Angel, 90.8ms
# image 2/16 /content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/Videos_Test/61wN0bSvL6L.jpg: 544x640 4 Goldfishs, 60.4ms
# image 3/16 /content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/Videos_Test/Guppy-and-goldfish.jpg: 320x640 1 Goldfish, 1 Angel, 70.2ms
# image 4/16 /content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/Videos_Test/Moscow-violet-guppy-pair.jpg: 640x640 1 Guppy, 8.0ms
# image 5/16 /content/drive/MyDrive/TrainYOLOv8CustomDataset/data/images/Videos_Test/Picture-3.png: 256x640 3 Goldfishs, 1 Guppy, 55.5ms
# ...
